# %%
import sys
import pandas as pd
import torch 
import os 

sys.path.append("../..")
# For retrieval

from langchain.vectorstores import Chroma
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.docstore.document import Document
from sentence_transformers import CrossEncoder
from langchain.text_splitter import RecursiveCharacterTextSplitter
from chunkers import TableExtractor

from financerag.tasks import MultiHiertt

# %% [markdown]
# ## Read Data

# %%
task = MultiHiertt()

# %%
queries = task.queries
query_df = pd.DataFrame(queries.values(), index=queries.keys(), columns=["query"])

# %%
documents = task.corpus
documents_df = pd.DataFrame(documents.values(), index=documents.keys(), columns=["title", "text"])

# %%
def extract(text):
    array = text.split("\n")
    paragraph_lines = []
    table_lines = []

    for i, line in enumerate(array):

        if "|" not in line:
            paragraph_lines.append(i)
        else:
            table_lines.append(i)
        
    paragraphs = []

    paragraph = []

    for i in range(len(paragraph_lines)):

        if i == (len(paragraph_lines) - 1):
            paragraph.append(paragraph_lines[i])
            paragraphs.append(paragraph)
            break

        if (paragraph_lines[i] + 1) == paragraph_lines[i+1]:
            paragraph.append(paragraph_lines[i])

        else:
            paragraph.append(paragraph_lines[i])
            paragraphs.append(paragraph)
            paragraph = []

    paragraphs
    paragraphs_ = []

    for paragraph in paragraphs:
        start = paragraph[0]
        end = paragraph[-1]

        paragraphs_.append("\n".join(text.split("\n")[start:end+1]))

    tables = []

    table = []

    for i in range(len(table_lines)):
        
        if i == (len(table_lines) - 1):
            table.append(table_lines[i])
            tables.append(table)
            break

        if (table_lines[i] + 1) == table_lines[i+1]:
            table.append(table_lines[i])

        else:
            table.append(table_lines[i])
            tables.append(table)
            table = []

    tables
    tables_ = []

    for table in tables:
        start = table[0]
        end = table[-1]

        tables_.append("\n".join(text.split("\n")[start:end+1]))
        
    return paragraphs_, tables_

# %%
def purge(row):

    return_list = []

    for cell in row:
        if cell.strip() == "":
            continue

        if any(keyword in cell.strip().lower().split(" ")for keyword in ["(in", "millions", "thousands", "in", "dollars", "note", "thousands)", "millions)", "dollars)", "year", "ended", "december"]):
            continue    
            
        else:
            return_list.append(cell)
    
    return return_list

# %%
def clean(row):

    return_list = []

    for cell in row:

        if any(keyword in cell.strip().lower().split(" ")for keyword in ["(in", "millions", "thousands", "in", "dollars", "note", "thousands)", "millions)", "dollars)", "year", "ended", "december",
                                                                         "january", "february", "march", "april", "may", "june", "july", "august", "september", "october", "november",
                                                                         "(millions), (thousands)", "(dollars)", "millions), (dollars)"]):
            continue    
            
        else:
            return_list.append(cell)
    
    return return_list

# %%
def parse_table(table):
    
    levels = []

    for row in table:
        row = row.split(" ")
        level = 0
        for i, cell in enumerate(row):
            if cell == "|":
               level += 1
            elif cell == "":
                continue
            else:
                break
        levels.append(level)

    headers = []

    for level, row in zip(levels, table):
        if level > 1:
            table.remove(row)
            row = row.split("|")
            row = purge(row)
            headers.append(row)
    
    if headers == []:
        columns = [ column.strip() for column in table[0].split("|") if column.strip() != ""]
        columns = clean(columns)
        table.remove(table[0])
    else:
        columns_set = False
        
        for header in headers:
            if header != []:
                columns = header
                columns_set = True
                
        if not columns_set:
            columns = [ column.strip() for column in table[0].split("|") if column.strip() != ""]
            columns = clean(columns)
            table.remove(table[0])

    rows = []

    for row in table:
        row = row.split("|")[1:-1]
        row = clean(row)
        rows.append(row)
    
    if len(columns) < len(rows[0]):
        columns = [i for i in range(len(rows[0]) - len(columns))] + columns

    return pd.DataFrame(rows, columns=columns)

# %%
document_tables = {}

for id, text in documents_df["text"].items():
    try:
        paragraphs, tables = extract(text)
        
        if len(tables) == 0:
            document_tables[id] = []

        table_dict = {}

        for i, table in enumerate(tables):
            table = table.split("\n")
            table = parse_table(table)
            table_dict[f"Table-{i}"] = table
            document_tables[id] = table_dict

    except Exception as e:
        print(id)
        print(e)
        pass
# Out:
# d8d24b238
# 1 columns passed, passed data had 4 columns
# d8cc5eb18
# 3 columns passed, passed data had 4 columns
# d8aa1dd4c
# 4 columns passed, passed data had 6 columns
# d862755bc
# 6 columns passed, passed data had 13 columns
# d8d64e6fa
# 4 columns passed, passed data had 5 columns
# d8c6d6b6e
# 4 columns passed, passed data had 5 columns
# d89532536
# 8 columns passed, passed data had 9 columns
# d8eca4d96
# 8 columns passed, passed data had 9 columns
# d8c95a548
# 5 columns passed, passed data had 6 columns
# d87b35a48
# 10 columns passed, passed data had 11 columns
# d8e0b4d24
# 5 columns passed, passed data had 6 columns
# d8ea69f72
# 3 columns passed, passed data had 5 columns
# d87eff462
# 3 columns passed, passed data had 4 columns
# d89b1abec
# 2 columns passed, passed data had 3 columns
# d8c0c05ae
# 1 columns passed, passed data had 3 columns
# d8e0599ba
# 2 columns passed, passed data had 3 columns
# d8945848a
# 3 columns passed, passed data had 4 columns
# d8ef60922
# 1 columns passed, passed data had 5 columns
# d87851e1c
# 1 columns passed, passed data had 2 columns
# d81a04f30
# 3 columns passed, passed data had 4 columns
# d87c97d64
# 4 columns passed, passed data had 5 columns
# d89864556
# 6 columns passed, passed data had 7 columns
# d8740b920
# 1 columns passed, passed data had 4 columns
# d8c77398c
# 2 columns passed, passed data had 3 columns
# d863c233e
# 3 columns passed, passed data had 4 columns
# d88c35992
# 2 columns passed, passed data had 3 columns
# d86a21d10
# 6 columns passed, passed data had 9 columns
# d8ca743f2
# 4 columns passed, passed data had 5 columns
# d8f5d5bb8
# 4 columns passed, passed data had 7 columns
# d83c8ad0c
# 3 columns passed, passed data had 4 columns
# d88aec8ec
# 3 columns passed, passed data had 4 columns
# d8d1fd538
# 7 columns passed, passed data had 8 columns
# d8a6beb74
# 3 columns passed, passed data had 5 columns
# d88d78cc8
# 1 columns passed, passed data had 2 columns
# d89854f20
# 2 columns passed, passed data had 3 columns
# d86444744
# 3 columns passed, passed data had 4 columns
# d8b044586
# 4 columns passed, passed data had 5 columns
# d87e0e6f2
# 6 columns passed, passed data had 7 columns
# d81818a3c
# 4 columns passed, passed data had 5 columns
# d897ab2e0
# 9 columns passed, passed data had 10 columns
# d8b7a8e1c
# 6 columns passed, passed data had 7 columns
# d8ea5b13e
# 6 columns passed, passed data had 7 columns
# d87574cbc
# 4 columns passed, passed data had 5 columns
# d8b090760
# 5 columns passed, passed data had 6 columns
# d8a4a4320
# 3 columns passed, passed data had 5 columns
# d8bb01bb8
# 2 columns passed, passed data had 4 columns
# d8d1db1fe
# 4 columns passed, passed data had 5 columns
# d8cdc746e
# 8 columns passed, passed data had 9 columns
# d81decb70
# 2 columns passed, passed data had 3 columns
# d8d0fa55a
# 4 columns passed, passed data had 6 columns
# d8b3b76b4
# 3 columns passed, passed data had 4 columns
# d8b7e81ca
# 5 columns passed, passed data had 7 columns
# d85f771b2
# 5 columns passed, passed data had 6 columns
# d8292c544
# list index out of range
# d8ab28d04
# 1 columns passed, passed data had 2 columns
# d8c54000c
# 3 columns passed, passed data had 4 columns
# d8b52db6a
# 5 columns passed, passed data had 6 columns
# d8373b14e
# 5 columns passed, passed data had 4 columns
# d8a97f656
# 2 columns passed, passed data had 3 columns
# d8c127722
# 6 columns passed, passed data had 7 columns
# d8789c552
# 5 columns passed, passed data had 9 columns
# d8e4cbf8e
# 6 columns passed, passed data had 9 columns
# d8e62557e
# 5 columns passed, passed data had 8 columns
# d8c1c8c9e
# 6 columns passed, passed data had 7 columns
# d827068f0
# 2 columns passed, passed data had 3 columns
# d8ac57554
# 3 columns passed, passed data had 4 columns
# d829ed99c
# 4 columns passed, passed data had 5 columns
# d81e4fb4e
# 4 columns passed, passed data had 5 columns
# d86e8e04c
# 3 columns passed, passed data had 4 columns
# d8f40b4f4
# 8 columns passed, passed data had 9 columns
# d87068a48
# 3 columns passed, passed data had 4 columns
# d8def81c0
# 6 columns passed, passed data had 7 columns
# d885114f4
# 6 columns passed, passed data had 7 columns
# d8dd1347c
# 5 columns passed, passed data had 6 columns
# d89ca87fc
# 1 columns passed, passed data had 6 columns
# d8ec03d74
# 6 columns passed, passed data had 7 columns
# d8373b22a
# 3 columns passed, passed data had 4 columns
# d86d240bc
# 3 columns passed, passed data had 4 columns
# d8959cdc8
# 4 columns passed, passed data had 3 columns
# d877b0e54
# 4 columns passed, passed data had 3 columns
# d8f444cf4
# 5 columns passed, passed data had 4 columns
# d8b083934
# 4 columns passed, passed data had 5 columns
# d8b044658
# 4 columns passed, passed data had 5 columns
# d8f26f53c
# 3 columns passed, passed data had 4 columns
# d88a7a594
# 4 columns passed, passed data had 5 columns
# d88791ec2
# 4 columns passed, passed data had 5 columns
# d8e579f30
# 5 columns passed, passed data had 9 columns
# d8b1d27d6
# 10 columns passed, passed data had 11 columns
# d87acf00e
# 4 columns passed, passed data had 5 columns
# d8dce4eba
# 3 columns passed, passed data had 4 columns
# d8f529c00
# 8 columns passed, passed data had 9 columns
# d89ec48d8
# 2 columns passed, passed data had 3 columns
# d888db08a
# 1 columns passed, passed data had 5 columns
# d89b31b26
# 3 columns passed, passed data had 4 columns
# d85ee0956
# 4 columns passed, passed data had 5 columns
# d876fa082
# 4 columns passed, passed data had 7 columns
# d8a2425b4
# 2 columns passed, passed data had 4 columns
# d8dd01100
# 4 columns passed, passed data had 6 columns
# d8d2c9bce
# 2 columns passed, passed data had 3 columns
# d8826ed5a
# 4 columns passed, passed data had 5 columns
# d88c35866
# 2 columns passed, passed data had 3 columns
# d89c92baa
# 8 columns passed, passed data had 9 columns
# d890e026c
# 4 columns passed, passed data had 5 columns
# d85db9e9c
# 2 columns passed, passed data had 3 columns
# d87085e54
# 2 columns passed, passed data had 3 columns
# d882e5842
# 4 columns passed, passed data had 9 columns
# d85ff2ce0
# 6 columns passed, passed data had 7 columns
# d8e3fa1c8
# 3 columns passed, passed data had 4 columns
# d866ce2a8
# 2 columns passed, passed data had 3 columns
# d879e4356
# 2 columns passed, passed data had 5 columns
# d838f1e52
# 4 columns passed, passed data had 5 columns
# d8d1fd4e8
# 6 columns passed, passed data had 8 columns
# d8606f236
# 4 columns passed, passed data had 5 columns
# d8d5fee66
# 7 columns passed, passed data had 8 columns
# d8a0e3dc6
# 4 columns passed, passed data had 5 columns
# d8bcb8524
# 3 columns passed, passed data had 4 columns
# d886f80ce
# 1 columns passed, passed data had 4 columns
# d8a255e48
# 3 columns passed, passed data had 4 columns
# d8d33013a
# 3 columns passed, passed data had 4 columns
# d89710f92
# 6 columns passed, passed data had 7 columns
# d88a7a486
# 5 columns passed, passed data had 6 columns
# d8612d998
# 3 columns passed, passed data had 4 columns
# d8746a61e
# 4 columns passed, passed data had 5 columns
# d8f303f48
# 2 columns passed, passed data had 3 columns
# d8908b58c
# 8 columns passed, passed data had 9 columns
# d8da9f876
# 4 columns passed, passed data had 5 columns
# d8b5c2aee
# 4 columns passed, passed data had 5 columns
# d88aec766
# 9 columns passed, passed data had 10 columns
# d8366a422
# 4 columns passed, passed data had 5 columns
# d87b9bd7a
# 3 columns passed, passed data had 4 columns
# d825901a6
# 4 columns passed, passed data had 6 columns
# d824fcf78
# 4 columns passed, passed data had 5 columns
# d873fec2a
# 4 columns passed, passed data had 5 columns
# d89b097c0
# 2 columns passed, passed data had 4 columns
# d81b7d86c
# 9 columns passed, passed data had 10 columns
# d8e4da75a
# 3 columns passed, passed data had 9 columns
# d8a120898
# 1 columns passed, passed data had 2 columns
# d89a25642
# 4 columns passed, passed data had 5 columns
# d87b80228
# 1 columns passed, passed data had 2 columns
# d8151169a
# 2 columns passed, passed data had 3 columns
# d8bd4baa4
# 2 columns passed, passed data had 3 columns
# d89ac63d0
# 3 columns passed, passed data had 4 columns
# d86f84a50
# 3 columns passed, passed data had 4 columns
# d8f8aa8e8
# 1 columns passed, passed data had 2 columns
# d8e6256a0
# 6 columns passed, passed data had 7 columns
# d86b15e88
# 3 columns passed, passed data had 4 columns
# d88bf53f6
# 7 columns passed, passed data had 8 columns
# d8c23f8da
# 4 columns passed, passed data had 5 columns
# d8add2c26
# 4 columns passed, passed data had 5 columns
# d864c92e6
# 3 columns passed, passed data had 4 columns
# d8977486c
# 3 columns passed, passed data had 4 columns
# d8c5fb08c
# 4 columns passed, passed data had 5 columns
# d88fd8d2e
# 4 columns passed, passed data had 5 columns
# d8e3bfd70
# 5 columns passed, passed data had 6 columns
# d890b88d4
# 3 columns passed, passed data had 4 columns
# d8c27974c
# 5 columns passed, passed data had 6 columns
# d8a149c34
# 5 columns passed, passed data had 6 columns
# d871513e2
# 3 columns passed, passed data had 4 columns
# d89504adc
# 4 columns passed, passed data had 6 columns
# d877e0bae
# 5 columns passed, passed data had 6 columns
# d8bc8d216
# 2 columns passed, passed data had 3 columns
# d8dba39e8
# 2 columns passed, passed data had 3 columns
# d8c692c84
# 1 columns passed, passed data had 2 columns
# d8a97f7fa
# 3 columns passed, passed data had 4 columns
# d8957e56c
# 4 columns passed, passed data had 6 columns
# d80f0a882
# 2 columns passed, passed data had 3 columns
# d8c4c9ba0
# 4 columns passed, passed data had 7 columns
# d8aeee01a
# 4 columns passed, passed data had 5 columns
# d896d2f44
# 4 columns passed, passed data had 6 columns
# d898c4456
# 5 columns passed, passed data had 6 columns
# d82aee6fc
# 4 columns passed, passed data had 5 columns
# d8ed318b8
# 6 columns passed, passed data had 11 columns
# d8b37878e
# 3 columns passed, passed data had 4 columns
# d8f7acea0
# 3 columns passed, passed data had 4 columns
# d87ee57ce
# 3 columns passed, passed data had 4 columns
# d8e23967c
# 2 columns passed, passed data had 3 columns
# d89a384fe
# 3 columns passed, passed data had 4 columns
# d8aeb4842
# 5 columns passed, passed data had 6 columns
# d8cbb1f44
# 6 columns passed, passed data had 7 columns
# d8a4885bc
# 5 columns passed, passed data had 8 columns
# d8dd8d4f2
# 2 columns passed, passed data had 3 columns
# d88778f9e
# list index out of range
# d89e28a14
# 6 columns passed, passed data had 7 columns
# d89b680cc
# 6 columns passed, passed data had 9 columns
# d8cd01188
# 4 columns passed, passed data had 5 columns
# d8e2396e0
# 2 columns passed, passed data had 3 columns
# d8b445612
# 2 columns passed, passed data had 3 columns
# d864a8af0
# 2 columns passed, passed data had 3 columns
# d86a8753e
# 3 columns passed, passed data had 4 columns
# d87772046
# 4 columns passed, passed data had 5 columns
# d8acd36e0
# 6 columns passed, passed data had 7 columns
# d89e28a82
# 3 columns passed, passed data had 5 columns
# d8a6e6fd4
# 10 columns passed, passed data had 11 columns
# d8bd86d98
# 4 columns passed, passed data had 5 columns
# d8ce142d2
# 6 columns passed, passed data had 7 columns
# d82729ada
# 3 columns passed, passed data had 4 columns
# d82375240
# 2 columns passed, passed data had 3 columns
# d8ad5a9f6
# 1 columns passed, passed data had 4 columns
# d86e3849e
# 6 columns passed, passed data had 9 columns
# d8f3eb2a8
# 9 columns passed, passed data had 10 columns
# d87b01e96
# 5 columns passed, passed data had 9 columns
# d8ea0ede8
# 3 columns passed, passed data had 4 columns
# d8d415500
# 1 columns passed, passed data had 4 columns
# d88be204e
# 9 columns passed, passed data had 10 columns
# d88a71106
# 3 columns passed, passed data had 4 columns
# d8a606984
# 12 columns passed, passed data had 13 columns
# d89854f98
# 5 columns passed, passed data had 6 columns
# d8ab7ea24
# 6 columns passed, passed data had 7 columns
# d86c04c36
# 9 columns passed, passed data had 13 columns
# d8259f318
# 4 columns passed, passed data had 5 columns
# d88e6bfd6
# 2 columns passed, passed data had 3 columns
# d895ff360
# 2 columns passed, passed data had 3 columns
# d89813a16
# 4 columns passed, passed data had 5 columns
# d8ee11ce2
# 4 columns passed, passed data had 5 columns
# d896c46ce
# 2 columns passed, passed data had 3 columns
# d8885235c
# 1 columns passed, passed data had 6 columns
# d8f36b8be
# 2 columns passed, passed data had 3 columns
# d881ef1b8
# 5 columns passed, passed data had 6 columns
# d88d5e53a
# 3 columns passed, passed data had 4 columns
# d814987e0
# 4 columns passed, passed data had 5 columns
# d8f43c32e
# 10 columns passed, passed data had 11 columns
# d8e325450
# 7 columns passed, passed data had 8 columns
# d8ea4e01a
# 4 columns passed, passed data had 5 columns
# d88589832
# 4 columns passed, passed data had 5 columns
# d8889de10
# 2 columns passed, passed data had 3 columns
# d8c518e6c
# 4 columns passed, passed data had 5 columns
# d8dc2386e
# 8 columns passed, passed data had 9 columns
# d8e16fe3a
# 5 columns passed, passed data had 6 columns
# d88ec564e
# 2 columns passed, passed data had 3 columns
# d8b477afe
# 3 columns passed, passed data had 4 columns
# d8b8ed264
# 9 columns passed, passed data had 10 columns
# d88a4a132
# 4 columns passed, passed data had 5 columns
# d8b4b0674
# 4 columns passed, passed data had 5 columns
# d8cc6f986
# 4 columns passed, passed data had 6 columns
# d8e56167e
# 5 columns passed, passed data had 6 columns
# d815cd25a
# 3 columns passed, passed data had 6 columns
# d8f8aa8a2
# 6 columns passed, passed data had 7 columns
# d8d8f5ea8
# 6 columns passed, passed data had 7 columns
# d81c799fa
# 3 columns passed, passed data had 4 columns
# d8622c5a6
# 4 columns passed, passed data had 5 columns
# d8972a6d6
# 4 columns passed, passed data had 5 columns
# d87019b46
# 7 columns passed, passed data had 8 columns
# d8b7367e0
# 4 columns passed, passed data had 5 columns
# d87b3591c
# 4 columns passed, passed data had 6 columns
# d88318aa8
# 2 columns passed, passed data had 3 columns
# d8aae8aa6
# 3 columns passed, passed data had 4 columns
# d888522ee
# 1 columns passed, passed data had 6 columns
# d89d37434
# 5 columns passed, passed data had 6 columns
# d8c28a902
# 2 columns passed, passed data had 3 columns
# d87da9b94
# 2 columns passed, passed data had 3 columns
# d8955b986
# 2 columns passed, passed data had 3 columns
# d8130c5ca
# 4 columns passed, passed data had 6 columns
# d8ee543b2
# 3 columns passed, passed data had 4 columns
# d89f60bd4
# 4 columns passed, passed data had 5 columns
# d86d88d00
# 8 columns passed, passed data had 9 columns
# d8237510a
# 3 columns passed, passed data had 4 columns
# d8b1baa0a
# 4 columns passed, passed data had 5 columns
# d868c1696
# 3 columns passed, passed data had 4 columns
# d8695f7e2
# 3 columns passed, passed data had 5 columns
# d88127cc6
# 6 columns passed, passed data had 7 columns
# d8aed1a0a
# 3 columns passed, passed data had 4 columns
# d883919a8
# 5 columns passed, passed data had 6 columns
# d8b611810
# 8 columns passed, passed data had 9 columns
# d8bf79902
# 2 columns passed, passed data had 3 columns
# d8e1e3a2e
# 3 columns passed, passed data had 4 columns
# d8f70d4cc
# 3 columns passed, passed data had 4 columns
# d84dc5eaa
# 8 columns passed, passed data had 9 columns
# d8ed989c8
# 3 columns passed, passed data had 5 columns
# d8c91595c
# 4 columns passed, passed data had 8 columns
# d894aff28
# 3 columns passed, passed data had 4 columns
# d8621525c
# 6 columns passed, passed data had 7 columns
# d81486d60
# 1 columns passed, passed data had 4 columns
# d8ac36d90
# 7 columns passed, passed data had 8 columns
# d811fbf64
# 6 columns passed, passed data had 7 columns
# d8ae71290
# 7 columns passed, passed data had 8 columns
# d8ecca230
# 12 columns passed, passed data had 13 columns
# d85f770a4
# 6 columns passed, passed data had 7 columns
# d8b962fa0
# 3 columns passed, passed data had 4 columns
# d87f7b49a
# 2 columns passed, passed data had 3 columns
# d8b9db338
# 7 columns passed, passed data had 8 columns
# d85fff4b8
# 6 columns passed, passed data had 7 columns
# d86052244
# 6 columns passed, passed data had 7 columns
# d8968e132
# 3 columns passed, passed data had 4 columns
# d8700527c
# 9 columns passed, passed data had 10 columns
# d8b4e965e
# 3 columns passed, passed data had 7 columns
# d8c22a07a
# 1 columns passed, passed data had 8 columns
# d8aefb5b2
# 3 columns passed, passed data had 4 columns
# d8e68d7b4
# 3 columns passed, passed data had 5 columns
# d8e95dcfa
# 5 columns passed, passed data had 6 columns
# d8b849164
# 6 columns passed, passed data had 7 columns
# d89774a38
# 5 columns passed, passed data had 8 columns
# d8b5b92be
# 6 columns passed, passed data had 7 columns
# d8199c9bc
# 2 columns passed, passed data had 3 columns
# d8f0dc3fa
# 4 columns passed, passed data had 5 columns
# d862f0a82
# 3 columns passed, passed data had 4 columns
# d885d3022
# 4 columns passed, passed data had 5 columns
# d861c8bdc
# 5 columns passed, passed data had 9 columns
# d8a411e08
# 2 columns passed, passed data had 3 columns
# d8d45d134
# 4 columns passed, passed data had 5 columns
# d8797956a
# 7 columns passed, passed data had 8 columns
# d8ba8007c
# 3 columns passed, passed data had 4 columns
# d8d86da08
# 2 columns passed, passed data had 4 columns
# d8ecb5e7a
# 7 columns passed, passed data had 8 columns
# d87053896
# 3 columns passed, passed data had 4 columns
# d8cf9f3ea
# 2 columns passed, passed data had 3 columns
# d8dc58a1e
# 4 columns passed, passed data had 5 columns
# d86e1fab6
# 5 columns passed, passed data had 6 columns
# d8ea5b1f2
# 1 columns passed, passed data had 2 columns
# d8983c010
# 3 columns passed, passed data had 1 columns
# d8b7f72ec
# 4 columns passed, passed data had 5 columns
# d8b190a66
# 2 columns passed, passed data had 4 columns
# d85f8acb2
# 2 columns passed, passed data had 4 columns
# d8d4f7112
# 6 columns passed, passed data had 7 columns
# d81447c00
# 5 columns passed, passed data had 6 columns
# d8bf5be66
# 6 columns passed, passed data had 7 columns
# d820400fc
# 3 columns passed, passed data had 4 columns
# d89a38666
# 3 columns passed, passed data had 4 columns
# d8e09d098
# 2 columns passed, passed data had 3 columns
# d8b10a70e
# 3 columns passed, passed data had 4 columns
# d8ab4aea4
# 6 columns passed, passed data had 9 columns
# d8b505106
# 5 columns passed, passed data had 6 columns
# d8f727804
# 4 columns passed, passed data had 5 columns
# d87903324
# 7 columns passed, passed data had 8 columns
# d8c05c054
# 2 columns passed, passed data had 3 columns
# d8efa6634
# 1 columns passed, passed data had 4 columns
# d828fb11a
# 4 columns passed, passed data had 5 columns
# d893820a6
# 4 columns passed, passed data had 5 columns
# d8c00bfa0
# 5 columns passed, passed data had 8 columns
# d88244cee
# 6 columns passed, passed data had 7 columns
# d8b13a634
# 6 columns passed, passed data had 5 columns
# d8bf28408
# 10 columns passed, passed data had 11 columns
# d86040102
# 5 columns passed, passed data had 6 columns
# d85e93d72
# 5 columns passed, passed data had 4 columns
# d86fac708
# 5 columns passed, passed data had 6 columns
# d88975806
# 6 columns passed, passed data had 7 columns
# d893f204a
# 4 columns passed, passed data had 5 columns
# d86d31154
# 4 columns passed, passed data had 5 columns
# d8bc63ede
# 5 columns passed, passed data had 6 columns
# d8f86de66
# 2 columns passed, passed data had 3 columns
# d8e64bbca
# 4 columns passed, passed data had 5 columns
# d8e62f8f8
# 3 columns passed, passed data had 4 columns
# d8ded89c4
# 3 columns passed, passed data had 4 columns
# d81392de6
# 5 columns passed, passed data had 6 columns
# d8ce46868
# 3 columns passed, passed data had 4 columns
# d8d960532
# 2 columns passed, passed data had 3 columns
# d89c03572
# 3 columns passed, passed data had 4 columns
# d87397e30
# 2 columns passed, passed data had 3 columns
# d8ac67ef4
# 4 columns passed, passed data had 6 columns
# d8ce2f410
# 4 columns passed, passed data had 5 columns
# d8a4806b4
# 12 columns passed, passed data had 13 columns
# d892ba0e2
# 5 columns passed, passed data had 8 columns
# d8dba3812
# 4 columns passed, passed data had 5 columns
# d8d96060e
# 1 columns passed, passed data had 6 columns
# d85dcd4f6
# 7 columns passed, passed data had 8 columns
# d8193ec72
# 4 columns passed, passed data had 5 columns
# d8632221c
# 7 columns passed, passed data had 8 columns
# d883affd4
# 5 columns passed, passed data had 6 columns
# d88f63bfa
# 4 columns passed, passed data had 5 columns
# d8880226c
# 3 columns passed, passed data had 6 columns
# d8b728460
# 1 columns passed, passed data had 6 columns
# d8da9f902
# 4 columns passed, passed data had 5 columns
# d8c5b6144
# 3 columns passed, passed data had 4 columns
# d89813c32
# 2 columns passed, passed data had 3 columns
# d8bbd0562
# 7 columns passed, passed data had 8 columns
# d86abb3ca
# 6 columns passed, passed data had 7 columns
# d8f838bc6
# 7 columns passed, passed data had 8 columns
# d8f2486ee
# 4 columns passed, passed data had 5 columns
# d89e3c726
# 5 columns passed, passed data had 6 columns
# d8df14d2a
# 3 columns passed, passed data had 4 columns
# d819e6468
# 4 columns passed, passed data had 5 columns
# d81b48aae
# 4 columns passed, passed data had 5 columns
# d82581f3e
# 4 columns passed, passed data had 5 columns
# d87559156
# 2 columns passed, passed data had 3 columns
# d874f9f9e
# 5 columns passed, passed data had 6 columns
# d8e29dda2
# 6 columns passed, passed data had 7 columns
# d86389e9e
# 4 columns passed, passed data had 6 columns
# d8ce5486e
# 4 columns passed, passed data had 5 columns
# d8b740a9c
# 4 columns passed, passed data had 5 columns
# d8771f0a8
# 2 columns passed, passed data had 4 columns
# d8bf90c88
# 4 columns passed, passed data had 5 columns
# d8b781ee8
# 2 columns passed, passed data had 3 columns
# d883cacbc
# 12 columns passed, passed data had 13 columns
# d87434b5e
# 6 columns passed, passed data had 7 columns
# d8d0257a6
# 3 columns passed, passed data had 4 columns
# d8e9eb6e0
# 3 columns passed, passed data had 4 columns
# d8beec4f8
# 4 columns passed, passed data had 6 columns
# d8e316dba
# 3 columns passed, passed data had 4 columns
# d8b661900
# 5 columns passed, passed data had 8 columns
# d8b044536
# 6 columns passed, passed data had 7 columns
# d8f2cb2ba
# 4 columns passed, passed data had 5 columns
# d8e88eaae
# 2 columns passed, passed data had 3 columns
# d87bac620
# 5 columns passed, passed data had 6 columns
# d8ef60a94
# 4 columns passed, passed data had 5 columns
# d8955bac6
# 6 columns passed, passed data had 7 columns
# d88f44142
# 4 columns passed, passed data had 5 columns
# d8239fc98
# 1 columns passed, passed data had 5 columns
# d815594ae
# 6 columns passed, passed data had 7 columns
# d869ea4dc
# 6 columns passed, passed data had 7 columns
# d8c1fedee
# 4 columns passed, passed data had 5 columns
# d8664f82c
# 4 columns passed, passed data had 8 columns
# d8b1ea386
# 1 columns passed, passed data had 3 columns
# d8efba5da
# 4 columns passed, passed data had 5 columns
# d8ed31994
# 4 columns passed, passed data had 5 columns
# d88143598
# 1 columns passed, passed data had 5 columns
# d8b3c9b16
# 2 columns passed, passed data had 3 columns
# d87e6bf8c
# 6 columns passed, passed data had 9 columns
# d87af088a
# 5 columns passed, passed data had 6 columns
# d86978fee
# 4 columns passed, passed data had 5 columns
# d8cd01110
# 4 columns passed, passed data had 5 columns
# d8789c49e
# 3 columns passed, passed data had 4 columns
# d827cc708
# 5 columns passed, passed data had 6 columns
# d8f696ca0
# 4 columns passed, passed data had 2 columns
# d8c70843e
# list index out of range
# d8f3d3932
# 12 columns passed, passed data had 13 columns
# d87180d86
# 4 columns passed, passed data had 5 columns
# d875591d8
# 6 columns passed, passed data had 7 columns
# d8af42b38
# 1 columns passed, passed data had 3 columns
# d888ccc4c
# 3 columns passed, passed data had 4 columns
# d8c1c8d48
# 2 columns passed, passed data had 5 columns
# d88c1719a
# 8 columns passed, passed data had 9 columns
# d81329026
# 3 columns passed, passed data had 4 columns
# d8d010a36
# 7 columns passed, passed data had 8 columns
# d8a9b5062
# 4 columns passed, passed data had 5 columns
# d8c60e13c
# 4 columns passed, passed data had 5 columns
# d89f7048a
# 8 columns passed, passed data had 9 columns
# d8a951d8c
# 9 columns passed, passed data had 10 columns
# d8f4e1144
# 5 columns passed, passed data had 6 columns
# d85d724d4
# 2 columns passed, passed data had 3 columns
# d8f73def6
# 4 columns passed, passed data had 5 columns
# d8843b1ec
# 12 columns passed, passed data had 13 columns
# d861e38ce
# 2 columns passed, passed data had 3 columns
# d8f7e6da8
# 7 columns passed, passed data had 8 columns
# d8cb482ec
# 5 columns passed, passed data had 8 columns
# d8612dae2
# 3 columns passed, passed data had 4 columns
# d8c043964
# 5 columns passed, passed data had 6 columns
# d8ea8bcd0
# 2 columns passed, passed data had 3 columns
# d87479920
# 9 columns passed, passed data had 10 columns
# d8a531946
# 2 columns passed, passed data had 3 columns
# d8bfc299a
# 1 columns passed, passed data had 7 columns
# d8714501a
# 4 columns passed, passed data had 1 columns
# d8a6c7b70
# 5 columns passed, passed data had 6 columns
# d8806fce8
# 7 columns passed, passed data had 8 columns
# d89c1ccf2
# 7 columns passed, passed data had 8 columns
# d8c3dd5b6
# 3 columns passed, passed data had 4 columns
# d815c514a
# 5 columns passed, passed data had 6 columns
# d8d39c970
# 1 columns passed, passed data had 5 columns
# d865beeee
# 9 columns passed, passed data had 10 columns
# d88540204
# 4 columns passed, passed data had 6 columns
# d8ef0c660
# 4 columns passed, passed data had 5 columns
# d86ce3d1e
# 2 columns passed, passed data had 3 columns
# d8e503d76
# 1 columns passed, passed data had 4 columns
# d838d65da
# 2 columns passed, passed data had 3 columns
# d889a7f18
# 4 columns passed, passed data had 5 columns
# d87c97f12
# 4 columns passed, passed data had 5 columns
# d8808fac0
# 5 columns passed, passed data had 6 columns
# d86b7bfee
# 5 columns passed, passed data had 6 columns
# d870403f4
# 1 columns passed, passed data had 6 columns
# d8721b066
# 5 columns passed, passed data had 6 columns
# d8e69ffd6
# 6 columns passed, passed data had 8 columns
# d8b0249d4
# 8 columns passed, passed data had 9 columns
# d868d9700
# 10 columns passed, passed data had 11 columns
# d8ecb5e20
# 6 columns passed, passed data had 7 columns
# d8ec31792
# 8 columns passed, passed data had 9 columns
# d873d5294
# 4 columns passed, passed data had 5 columns
# d891db036
# 2 columns passed, passed data had 5 columns
# d8f4ed98a
# 3 columns passed, passed data had 4 columns
# d87876bfe
# 4 columns passed, passed data had 5 columns
# d8f3eb140
# 1 columns passed, passed data had 2 columns
# d8c86908a
# 6 columns passed, passed data had 4 columns
# d8d698b60
# 5 columns passed, passed data had 6 columns
# d89aed412
# 8 columns passed, passed data had 9 columns
# d88975856
# 6 columns passed, passed data had 7 columns
# d8b813622
# 1 columns passed, passed data had 6 columns
# d8d46fc44
# 6 columns passed, passed data had 7 columns
# d8118097c
# 9 columns passed, passed data had 10 columns
# d8816fdc8
# 2 columns passed, passed data had 3 columns
# d83374420
# 5 columns passed, passed data had 8 columns
# d8e08335a
# 6 columns passed, passed data had 7 columns
# d8402e864
# 6 columns passed, passed data had 7 columns
# d8a2e98c8
# 4 columns passed, passed data had 5 columns
# d815895aa
# 9 columns passed, passed data had 10 columns
# d8873b0f4
# 5 columns passed, passed data had 6 columns
# d89b9a9a0
# 1 columns passed, passed data had 3 columns
# d8a255da8
# 4 columns passed, passed data had 5 columns
# d8d480d6e
# 6 columns passed, passed data had 5 columns
# d8865d95c
# 8 columns passed, passed data had 9 columns
# d8bdb73a8
# 5 columns passed, passed data had 6 columns
# d8a02a06a
# 8 columns passed, passed data had 9 columns
# d8124317a
# 4 columns passed, passed data had 6 columns
# d8ac2a61c
# 4 columns passed, passed data had 5 columns
# d81ffbb3c
# 9 columns passed, passed data had 10 columns
# d864d2044
# 2 columns passed, passed data had 3 columns
# d8c7d2bbc
# 4 columns passed, passed data had 5 columns
# d8d1c5e12
# 7 columns passed, passed data had 8 columns
# d8a9b4ffe
# 4 columns passed, passed data had 5 columns
# d838d6576
# 4 columns passed, passed data had 5 columns
# d81329094
# 6 columns passed, passed data had 7 columns
# d8a7c2502
# 5 columns passed, passed data had 6 columns
# d8199ca70
# 2 columns passed, passed data had 3 columns
# d8da46974
# 5 columns passed, passed data had 6 columns
# d8e2e88ca
# 1 columns passed, passed data had 2 columns
# d890fbc4c
# 4 columns passed, passed data had 5 columns
# d8b72851e
# 2 columns passed, passed data had 1 columns
# d8f4a85ec
# 4 columns passed, passed data had 5 columns
# d83b5a036
# 4 columns passed, passed data had 5 columns
# d82a93cf2
# 3 columns passed, passed data had 4 columns
# d866053bc
# 5 columns passed, passed data had 6 columns
# d89d0b1e0
# 2 columns passed, passed data had 3 columns
# d88391926
# 3 columns passed, passed data had 4 columns
# d8888e078
# 5 columns passed, passed data had 6 columns
# d8ad5a9a6
# 1 columns passed, passed data had 6 columns
# d8e436060
# 3 columns passed, passed data had 7 columns
# d87a70a72
# 6 columns passed, passed data had 7 columns
# d86feb692
# 8 columns passed, passed data had 9 columns
# d8807da50
# 3 columns passed, passed data had 4 columns
# d8ec8225a
# list index out of range
# d8df988fa
# 6 columns passed, passed data had 7 columns
# d88a2ab2a
# 3 columns passed, passed data had 7 columns
# d8e2395be
# 4 columns passed, passed data had 6 columns
# d8805f000
# 3 columns passed, passed data had 8 columns
# d85f76f64
# 5 columns passed, passed data had 6 columns
# d88e61db0
# 4 columns passed, passed data had 5 columns
# d875c518a
# 5 columns passed, passed data had 8 columns
# d8d3d33e4
# 2 columns passed, passed data had 3 columns
# d8177a9b8
# 3 columns passed, passed data had 4 columns
# d8f0a7236
# 3 columns passed, passed data had 5 columns
# d8932b904
# 11 columns passed, passed data had 12 columns
# d8c07e208
# 4 columns passed, passed data had 5 columns
# d88f876ea
# 8 columns passed, passed data had 9 columns
# d8d9d0a08
# 3 columns passed, passed data had 6 columns
# d8de223fe
# 2 columns passed, passed data had 3 columns
# d8bf4f0da
# 6 columns passed, passed data had 7 columns
# d8e16ff66
# 3 columns passed, passed data had 4 columns
# d8ca5485e
# 1 columns passed, passed data had 5 columns
# d8d3c5618
# 8 columns passed, passed data had 9 columns
# d87ec1b80
# 4 columns passed, passed data had 5 columns
# d86b5f0c4
# 7 columns passed, passed data had 8 columns
# d8883c160
# 3 columns passed, passed data had 4 columns
# d8d44bef2
# 9 columns passed, passed data had 10 columns
# d86df4e2e
# 4 columns passed, passed data had 7 columns
# d8e7cc878
# 3 columns passed, passed data had 4 columns
# d8db949d4
# 4 columns passed, passed data had 5 columns
# d8c9e1e94
# 1 columns passed, passed data had 2 columns
# d81392eae
# 2 columns passed, passed data had 5 columns
# d8bdb7434
# 4 columns passed, passed data had 5 columns
# d835c7272
# 2 columns passed, passed data had 3 columns
# d8b7a8d18
# 7 columns passed, passed data had 8 columns
# d86fbf9ca
# 4 columns passed, passed data had 6 columns
# d8771f1c0
# 2 columns passed, passed data had 3 columns
# d8ddb696a
# 7 columns passed, passed data had 8 columns
# d8d6f4442
# 3 columns passed, passed data had 5 columns
# d8943f372
# 6 columns passed, passed data had 7 columns
# d86d9ff82
# 4 columns passed, passed data had 5 columns
# d87fdd5a0
# 6 columns passed, passed data had 7 columns
# d86c04ce0
# 4 columns passed, passed data had 7 columns
# d8ee997e6
# 5 columns passed, passed data had 6 columns
# d897ab222
# 4 columns passed, passed data had 5 columns
# d823e9b0e
# list index out of range
# d8a02a010
# 1 columns passed, passed data had 4 columns
# d867a35c0
# 3 columns passed, passed data had 4 columns
# d8d3d345c
# 4 columns passed, passed data had 6 columns
# d8870b408
# 2 columns passed, passed data had 3 columns
# d8a49a23a
# 5 columns passed, passed data had 9 columns
# d82787a22
# 3 columns passed, passed data had 4 columns
# d890cdc8e
# 2 columns passed, passed data had 3 columns
# d8b40666a
# 3 columns passed, passed data had 4 columns
# d86aa3f2c
# 4 columns passed, passed data had 5 columns
# d8d569dde
# 8 columns passed, passed data had 9 columns
# d8e1f7448
# 2 columns passed, passed data had 3 columns
# d8193ebe6
# 3 columns passed, passed data had 4 columns
# d883e6c8c
# 6 columns passed, passed data had 7 columns
# d8e5c1100
# 8 columns passed, passed data had 9 columns
# d8f7e6ba0
# 9 columns passed, passed data had 10 columns
# d87ccfda4
# 12 columns passed, passed data had 13 columns
# d8c823f26
# 3 columns passed, passed data had 4 columns
# d8b3fe6ea
# 6 columns passed, passed data had 7 columns
# d820b0e60
# 2 columns passed, passed data had 3 columns
# d8623cf64
# 2 columns passed, passed data had 8 columns
# d89458548
# 6 columns passed, passed data had 9 columns
# d88f63b8c
# 4 columns passed, passed data had 5 columns
# d813330ee
# 3 columns passed, passed data had 4 columns
# d8775a5f4
# 9 columns passed, passed data had 10 columns
# d8e6131da
# 4 columns passed, passed data had 5 columns
# d86a2e5d8
# 3 columns passed, passed data had 4 columns
# d8be9babc
# 4 columns passed, passed data had 6 columns
# d88f63b28
# 4 columns passed, passed data had 5 columns
# d813ebdb0
# 4 columns passed, passed data had 5 columns
# d8bd4baf4
# 2 columns passed, passed data had 3 columns
# d898ef05c
# 5 columns passed, passed data had 6 columns
# d8d4c53e2
# 6 columns passed, passed data had 7 columns
# d8eca4eb8
# 3 columns passed, passed data had 4 columns
# d82267a42
# 3 columns passed, passed data had 4 columns
# d88e6bf36
# 4 columns passed, passed data had 5 columns
# d8bfcceea
# 4 columns passed, passed data had 6 columns
# d8ee058c0
# 1 columns passed, passed data had 3 columns
# d8a5c0006
# 5 columns passed, passed data had 6 columns
# d8c2797c4
# 3 columns passed, passed data had 4 columns
# d8d698976
# 3 columns passed, passed data had 4 columns
# d8dfa178e
# 4 columns passed, passed data had 5 columns
# d8e41ad2e
# 1 columns passed, passed data had 2 columns
# d8698915a
# 6 columns passed, passed data had 7 columns
# d84dc5fc2
# 4 columns passed, passed data had 5 columns
# d87085ecc
# 3 columns passed, passed data had 4 columns
# d8dc58b2c
# 5 columns passed, passed data had 9 columns
# d8152111c
# 6 columns passed, passed data had 7 columns
# d8ecca05a
# 4 columns passed, passed data had 5 columns
# d88d0bb0a
# 2 columns passed, passed data had 3 columns
# d8dc6d81a
# 3 columns passed, passed data had 4 columns
# d8786d022
# 3 columns passed, passed data had 4 columns
# d811aaf06
# 6 columns passed, passed data had 7 columns
# d8a65c65e
# 1 columns passed, passed data had 6 columns
# d877e0b04
# 2 columns passed, passed data had 3 columns
# d8c0ad120
# 1 columns passed, passed data had 2 columns
# d86abb316
# 2 columns passed, passed data had 3 columns
# d811c3808
# 3 columns passed, passed data had 4 columns
# d896ad42e
# 5 columns passed, passed data had 9 columns
# d85e00216
# 5 columns passed, passed data had 13 columns
# d87303a32
# 3 columns passed, passed data had 4 columns
# d8a0bcdb6
# 5 columns passed, passed data had 6 columns
# d8ae623b2
# 6 columns passed, passed data had 7 columns
# d89498c6a
# 3 columns passed, passed data had 4 columns
# d8cc02a98
# 5 columns passed, passed data had 6 columns
# d85da43b2
# 6 columns passed, passed data had 7 columns
# d8f8055aa
# 3 columns passed, passed data had 4 columns
# d8a5e5a0e
# 8 columns passed, passed data had 9 columns
# d8bb24a32
# 6 columns passed, passed data had 7 columns
# d8e73f1b2
# 9 columns passed, passed data had 10 columns
# d885113e6
# 6 columns passed, passed data had 7 columns
# d89151cb4
# 9 columns passed, passed data had 10 columns
# d8e0fbf9e
# 2 columns passed, passed data had 3 columns
# d8c043a04
# 5 columns passed, passed data had 6 columns
# d86e5817c
# 5 columns passed, passed data had 6 columns
# d8f0a73bc
# 4 columns passed, passed data had 5 columns
# d897e440a
# 10 columns passed, passed data had 11 columns
# d8f2c1864
# 6 columns passed, passed data had 8 columns
# d892970e2
# 6 columns passed, passed data had 9 columns
# d8f63aaae
# 3 columns passed, passed data had 4 columns
# d86b5f1b4
# 4 columns passed, passed data had 5 columns
# d8bcb8470
# 3 columns passed, passed data had 4 columns
# d8d2a59f4
# 6 columns passed, passed data had 7 columns
# d89d0b000
# 1 columns passed, passed data had 4 columns
# d8754921a
# 2 columns passed, passed data had 4 columns
# d87964e6c
# 2 columns passed, passed data had 3 columns
# d816dc6dc
# 4 columns passed, passed data had 8 columns
# d8c1091b4
# 4 columns passed, passed data had 5 columns
# d8bd86dfc
# 4 columns passed, passed data had 5 columns
# d811e944a
# 3 columns passed, passed data had 4 columns
# d89c6bb40
# 9 columns passed, passed data had 10 columns
# d88e61e14
# 3 columns passed, passed data had 4 columns
# d8a9f8772
# 9 columns passed, passed data had 10 columns
# d8a43f68c
# 6 columns passed, passed data had 7 columns
# d8e0fbe5e
# 9 columns passed, passed data had 10 columns
# d8dc7b00a
# 4 columns passed, passed data had 5 columns
# d889959ee
# 3 columns passed, passed data had 4 columns
# d8445e632
# 3 columns passed, passed data had 4 columns
# d88f7b976
# 2 columns passed, passed data had 3 columns
# d8c259118
# 9 columns passed, passed data had 11 columns
# d8cf63fc0
# 6 columns passed, passed data had 8 columns
# d871e165e
# 2 columns passed, passed data had 3 columns
# d891f8424
# 1 columns passed, passed data had 2 columns
# d8d5af488
# 4 columns passed, passed data had 5 columns
# d8c3051d4
# 3 columns passed, passed data had 4 columns
# d87e0e8aa
# 4 columns passed, passed data had 5 columns
# d8f458fc4
# 6 columns passed, passed data had 7 columns
# d8d1462de
# 2 columns passed, passed data had 3 columns
# d8f7cdef2
# 5 columns passed, passed data had 6 columns
# d8b4b05e8
# 4 columns passed, passed data had 6 columns
# d880433a0
# 2 columns passed, passed data had 3 columns
# d8a49a168
# 5 columns passed, passed data had 6 columns
# d883874b2
# 5 columns passed, passed data had 6 columns
# d88552300
# 7 columns passed, passed data had 8 columns
# d8ac21a58
# 4 columns passed, passed data had 5 columns
# d88d0bb64
# 4 columns passed, passed data had 5 columns
# d8cc919be
# 4 columns passed, passed data had 6 columns
# d864c9296
# 9 columns passed, passed data had 10 columns
# d886121d2
# 5 columns passed, passed data had 6 columns
# d81decc1a
# 4 columns passed, passed data had 7 columns
# d885b63be
# 6 columns passed, passed data had 8 columns
# d891c7004
# 2 columns passed, passed data had 4 columns
# d8ac9fed0
# 6 columns passed, passed data had 9 columns
# d8bb12af8
# 1 columns passed, passed data had 5 columns
# d8dd55796
# 11 columns passed, passed data had 12 columns
# d8c37cdce
# 4 columns passed, passed data had 5 columns
# d89b0986a
# 1 columns passed, passed data had 4 columns
# d8160f43e
# 3 columns passed, passed data had 4 columns
# d8da8a214
# 4 columns passed, passed data had 5 columns
# d8b910638
# 1 columns passed, passed data had 2 columns
# d8c88249a
# 5 columns passed, passed data had 6 columns
# d89913416
# 3 columns passed, passed data had 4 columns
# d8ec685c6
# 3 columns passed, passed data had 4 columns
# d8f8057b2
# 6 columns passed, passed data had 7 columns
# d8e75807c
# 5 columns passed, passed data had 6 columns
# d8883c23c
# 6 columns passed, passed data had 7 columns
# d8ab978c6
# 7 columns passed, passed data had 8 columns
# d8d6c5f34
# 8 columns passed, passed data had 9 columns
# d8d42a8e2
# 6 columns passed, passed data had 7 columns
# d87a08bde
# 2 columns passed, passed data had 3 columns
# d8cf64060
# 2 columns passed, passed data had 3 columns
# d87b0fc6c
# 7 columns passed, passed data had 8 columns
# d8b16dc82
# 9 columns passed, passed data had 10 columns
# d818189c4
# 4 columns passed, passed data had 5 columns
# d898ddabe
# 6 columns passed, passed data had 5 columns
# d88afa578
# 1 columns passed, passed data had 2 columns
# d87cadb64
# 9 columns passed, passed data had 10 columns
# d86745a1a
# 4 columns passed, passed data had 5 columns
# d8ce91fac
# 3 columns passed, passed data had 4 columns
# d867cd1cc
# 2 columns passed, passed data had 3 columns
# d8b51fc0e
# 6 columns passed, passed data had 7 columns
# d811519d8
# 3 columns passed, passed data had 4 columns
# d8637aa66
# 9 columns passed, passed data had 10 columns
# d8f3eb546
# 9 columns passed, passed data had 10 columns
# d87809afe
# list index out of range
# d89028766
# 6 columns passed, passed data had 7 columns
# d88822710
# 5 columns passed, passed data had 6 columns
# d86e48678
# 4 columns passed, passed data had 5 columns
# d87bfca76
# 4 columns passed, passed data had 5 columns
# d8b9aa2e2
# 3 columns passed, passed data had 4 columns
# d8bee0af4
# 2 columns passed, passed data had 3 columns
# d8198bf9a
# 2 columns passed, passed data had 3 columns
# d8a0f7ab0
# 9 columns passed, passed data had 10 columns
# d8691c244
# 4 columns passed, passed data had 7 columns
# d8c017b34
# 7 columns passed, passed data had 8 columns
# d89c7a082
# 3 columns passed, passed data had 4 columns
# d861e3928
# 2 columns passed, passed data had 3 columns
# d8c9e1e26
# 6 columns passed, passed data had 7 columns
# d8d684ca0
# 4 columns passed, passed data had 5 columns
# d8622c6e6
# 2 columns passed, passed data had 3 columns
# d8a751dde
# 4 columns passed, passed data had 5 columns
# d8e16fee4
# 5 columns passed, passed data had 6 columns
# d82699f70
# 7 columns passed, passed data had 9 columns
# d88995976
# 3 columns passed, passed data had 4 columns
# d8f5af404
# 6 columns passed, passed data had 9 columns
# d8a9b524c
# 4 columns passed, passed data had 5 columns
# d87ec1c16
# 6 columns passed, passed data had 7 columns
# d8c1c8cf8
# 8 columns passed, passed data had 9 columns
# d8b6ddadc
# 6 columns passed, passed data had 8 columns
# d8a71df5c
# 2 columns passed, passed data had 3 columns
# d864959e6
# 6 columns passed, passed data had 7 columns
# d8e9eb7ee
# 5 columns passed, passed data had 6 columns
# d8c2351a0
# 4 columns passed, passed data had 5 columns
# d8da469d8
# 3 columns passed, passed data had 4 columns
# d8bc5c4a4
# 4 columns passed, passed data had 6 columns
# d8ea98476
# 6 columns passed, passed data had 7 columns
# d8ebde5b0
# 1 columns passed, passed data had 3 columns
# d8dd8d45c
# 4 columns passed, passed data had 5 columns
# d827ba6de
# 2 columns passed, passed data had 3 columns
# d8ae81500
# 1 columns passed, passed data had 4 columns
# d891682e8
# 9 columns passed, passed data had 10 columns
# d8e3d6be2
# 5 columns passed, passed data had 6 columns
# d8b39b22a
# 4 columns passed, passed data had 5 columns
# d8a7893f6
# 7 columns passed, passed data had 8 columns
# d877b0d0a
# 6 columns passed, passed data had 7 columns
# d8c7d2ab8
# 4 columns passed, passed data had 5 columns
# d883b0038
# 3 columns passed, passed data had 4 columns
# d8ef60b20
# 2 columns passed, passed data had 3 columns
# d8cef8220
# 4 columns passed, passed data had 5 columns
# d8a994ab0
# 4 columns passed, passed data had 5 columns
# d8a878460
# 5 columns passed, passed data had 6 columns
# d891c6e56
# 3 columns passed, passed data had 4 columns
# d89fd96f6
# 6 columns passed, passed data had 7 columns
# d8aacbb36
# 6 columns passed, passed data had 8 columns
# d815dd9fc
# 6 columns passed, passed data had 7 columns
# d8198bf04
# 5 columns passed, passed data had 9 columns
# d8aec3036
# 6 columns passed, passed data had 8 columns
# d8ead85c6
# 2 columns passed, passed data had 4 columns
# d810b791e
# 1 columns passed, passed data had 2 columns
# d875f1dac
# 1 columns passed, passed data had 4 columns
# d8e305a60
# 8 columns passed, passed data had 9 columns
# d8151164a
# 5 columns passed, passed data had 6 columns
# d8754940e
# 1 columns passed, passed data had 4 columns
# d8b083aba
# 4 columns passed, passed data had 5 columns
# d88c4b04e
# 3 columns passed, passed data had 4 columns
# d891ea91e
# 3 columns passed, passed data had 5 columns
# d8b9233fa
# 6 columns passed, passed data had 7 columns
# d861b4678
# 5 columns passed, passed data had 6 columns
# d8d1726c2
# 1 columns passed, passed data had 6 columns
# d89420940
# 8 columns passed, passed data had 9 columns
# d8f094758
# 3 columns passed, passed data had 4 columns
# d8c408284
# 4 columns passed, passed data had 5 columns
# d8e606002
# 4 columns passed, passed data had 5 columns
# d8ebc6ce4
# 4 columns passed, passed data had 5 columns
# d81151a82
# 5 columns passed, passed data had 6 columns
# d8366a472
# 7 columns passed, passed data had 5 columns
# d81f020dc
# 3 columns passed, passed data had 4 columns
# d891980e2
# 8 columns passed, passed data had 9 columns
# d8dea638e
# 7 columns passed, passed data had 8 columns
# d8bee0bda
# 4 columns passed, passed data had 3 columns
# d8d3e0fd0
# 4 columns passed, passed data had 5 columns
# d83b9f4b0
# 1 columns passed, passed data had 4 columns
# d88863ddc
# 1 columns passed, passed data had 4 columns
# d8c8130a4
# 3 columns passed, passed data had 4 columns
# d8e2cfa6e
# 4 columns passed, passed data had 6 columns
# d8cf0403e
# 5 columns passed, passed data had 6 columns
# d894c30dc
# 4 columns passed, passed data had 5 columns
# d810cc81e
# 2 columns passed, passed data had 3 columns
# d8e39a386
# 8 columns passed, passed data had 9 columns
# d8e1c123a
# 5 columns passed, passed data had 6 columns
# d8b97ef3e
# 6 columns passed, passed data had 7 columns
# d888db166
# 4 columns passed, passed data had 5 columns
# d8942099a
# 7 columns passed, passed data had 8 columns
# d889169f0
# 8 columns passed, passed data had 9 columns
# d82cf6b5c
# 5 columns passed, passed data had 7 columns
# d894eff4c
# 5 columns passed, passed data had 6 columns
# d8e8a662c
# 3 columns passed, passed data had 4 columns
# d8dfc2a7e
# 1 columns passed, passed data had 4 columns
# d815cd192
# 4 columns passed, passed data had 5 columns
# d8de982e8
# 6 columns passed, passed data had 7 columns
# d87e0e7ce
# 3 columns passed, passed data had 4 columns
# d8b6dd924
# 4 columns passed, passed data had 5 columns
# d86a21c98
# 9 columns passed, passed data had 10 columns
# d828fb160
# 4 columns passed, passed data had 5 columns
# d8d9f1898
# 7 columns passed, passed data had 8 columns
# d89151bc4
# 5 columns passed, passed data had 6 columns
# d8eabdf96
# 4 columns passed, passed data had 8 columns
# d8dcca04c
# 4 columns passed, passed data had 5 columns
# d8b16dbd8
# 4 columns passed, passed data had 5 columns
# d88fd8e64
# 1 columns passed, passed data had 5 columns
# d867cd2e4
# 11 columns passed, passed data had 12 columns
# d87fc1c06
# 4 columns passed, passed data had 5 columns
# d8b505156
# 4 columns passed, passed data had 5 columns
# d8989918e
# 1 columns passed, passed data had 2 columns
# d8c9cf7da
# 3 columns passed, passed data had 7 columns
# d8e4aa564
# 2 columns passed, passed data had 5 columns
# d8d2957f2
# 6 columns passed, passed data had 7 columns
# d86dfdbbe
# 3 columns passed, passed data had 4 columns
# d81b7d812
# 6 columns passed, passed data had 7 columns
# d8d42a784
# 4 columns passed, passed data had 6 columns
# d88318b84
# 4 columns passed, passed data had 5 columns
# d8445e6a0
# 2 columns passed, passed data had 3 columns
# d8954de94
# 4 columns passed, passed data had 5 columns
# d87fdd44c
# 5 columns passed, passed data had 6 columns
# d81317164
# 6 columns passed, passed data had 7 columns
# d8ac2a586
# 4 columns passed, passed data had 5 columns
# d89392eec
# 4 columns passed, passed data had 5 columns
# d8de98252
# 2 columns passed, passed data had 3 columns
# d818cb592
# 3 columns passed, passed data had 4 columns
# d8784315a
# 3 columns passed, passed data had 4 columns
# d865d58b0
# 6 columns passed, passed data had 7 columns
# d88c4b18e
# 3 columns passed, passed data had 4 columns
# d8c71201a
# 3 columns passed, passed data had 4 columns
# d8caae958
# 2 columns passed, passed data had 3 columns
# d88fd8ee6
# 2 columns passed, passed data had 3 columns
# d823751e6
# 4 columns passed, passed data had 6 columns
# d8957e68e
# 8 columns passed, passed data had 9 columns
# d894b0054
# 4 columns passed, passed data had 6 columns
# d81511794
# 2 columns passed, passed data had 3 columns
# d8d590bfa
# 6 columns passed, passed data had 7 columns
# d86ec35c6
# 6 columns passed, passed data had 7 columns
# d8b7593d0
# 6 columns passed, passed data had 7 columns
# d8ec31648
# 4 columns passed, passed data had 5 columns
# d8e3eb77c
# 4 columns passed, passed data had 5 columns
# d87f4fd7c
# 4 columns passed, passed data had 3 columns
# d8e5e583e
# 4 columns passed, passed data had 6 columns
# d86c6676a
# 8 columns passed, passed data had 9 columns
# d8d9f1802
# 7 columns passed, passed data had 8 columns
# d8acc08c4
# 8 columns passed, passed data had 9 columns
# d875b8d18
# 3 columns passed, passed data had 9 columns
# d8cd2160e
# 2 columns passed, passed data had 3 columns
# d8f748478
# 1 columns passed, passed data had 4 columns
# d8c555182
# 10 columns passed, passed data had 11 columns
# d8177a896
# 9 columns passed, passed data had 10 columns
# d88d22e5e
# 3 columns passed, passed data had 4 columns
# d81139478
# 3 columns passed, passed data had 6 columns
# d8d5049a2
# 6 columns passed, passed data had 7 columns
# d87445238
# 4 columns passed, passed data had 7 columns
# d8c0f5c22
# 10 columns passed, passed data had 11 columns
# d8b6f9994
# 4 columns passed, passed data had 5 columns
# d8d4984be
# 3 columns passed, passed data had 4 columns
# d860fdf18
# 2 columns passed, passed data had 3 columns
# d894c2fd8
# 2 columns passed, passed data had 3 columns
# d8a8410b4
# 5 columns passed, passed data had 6 columns
# d816bd994
# 5 columns passed, passed data had 6 columns
# d8a51094e
# 3 columns passed, passed data had 4 columns
# d8e1a7ea2
# 6 columns passed, passed data had 7 columns
# d875f1cee
# 4 columns passed, passed data had 5 columns
# d8771f0ee
# 3 columns passed, passed data had 4 columns
# d8f3d38b0
# 3 columns passed, passed data had 4 columns
# d8992644e
# 3 columns passed, passed data had 4 columns
# d885792ac
# 9 columns passed, passed data had 10 columns
# d87290578
# 7 columns passed, passed data had 8 columns
# d8f77068a
# 4 columns passed, passed data had 5 columns
# d86f5c884
# 4 columns passed, passed data had 6 columns
# d8bf5bf24
# 3 columns passed, passed data had 4 columns
# d8ed98c98
# 4 columns passed, passed data had 5 columns
# d886a1080
# 6 columns passed, passed data had 10 columns
# d86ae82f8
# 3 columns passed, passed data had 4 columns
# d8f1dad60
# 5 columns passed, passed data had 6 columns
# d8d1725aa
# 2 columns passed, passed data had 3 columns
# d8cea6632
# 4 columns passed, passed data had 8 columns
# d892b089e
# ...
# d8d07eb26
# 4 columns passed, passed data had 5 columns
# d87c65260
# 3 columns passed, passed data had 4 columns
# d89413024
# 1 columns passed, passed data had 5 columns
# d8670e844
# 1 columns passed, passed data had 5 columns
# d8ac80a94
# 6 columns passed, passed data had 7 columns
# d8cf9f3ae
# 2 columns passed, passed data had 3 columns
# d8e8a65c8
# 8 columns passed, passed data had 11 columns
# d8c3377b0
# 4 columns passed, passed data had 6 columns
# d89c7a122
# 2 columns passed, passed data had 3 columns
# d897544ea
# 4 columns passed, passed data had 5 columns
# d8a894b7e
# 3 columns passed, passed data had 4 columns
# d8143a348
# 8 columns passed, passed data had 9 columns
# d88116b42
# 5 columns passed, passed data had 6 columns
# d860fde14
# 3 columns passed, passed data had 4 columns
# d8d39ca06
# 1 columns passed, passed data had 2 columns
# d8cb48242
# 5 columns passed, passed data had 8 columns
# d8ba12f68
# 4 columns passed, passed data had 8 columns
# d84dc6030
# 9 columns passed, passed data had 10 columns
# d86feb584
# 4 columns passed, passed data had 5 columns
# d8f43c41e
# 3 columns passed, passed data had 2 columns
# d8b34cdc8
# 7 columns passed, passed data had 8 columns
# d8a6069de
# 4 columns passed, passed data had 9 columns
# d8e435ffc
# 3 columns passed, passed data had 7 columns
# d88e0d60c
# 1 columns passed, passed data had 5 columns
# d89381ff2
# 7 columns passed, passed data had 9 columns
# d89e5451a
# 5 columns passed, passed data had 6 columns
# d8cdc72c0
# 2 columns passed, passed data had 3 columns
# d8c57dbaa
# 4 columns passed, passed data had 6 columns
# d8a994b8c
# 6 columns passed, passed data had 7 columns
# d8ba20e42
# 6 columns passed, passed data had 7 columns
# d8a894af2
# 3 columns passed, passed data had 4 columns
# d8aefb440
# 8 columns passed, passed data had 9 columns
# d8cb2d618
# 4 columns passed, passed data had 5 columns
# d8740b7e0
# 3 columns passed, passed data had 4 columns
# d8d24b35a
# 3 columns passed, passed data had 5 columns
# d8988f558
# 5 columns passed, passed data had 6 columns
# d8b3e3192
# 9 columns passed, passed data had 10 columns
# d8d4a9e30
# 2 columns passed, passed data had 3 columns
# d86f3d9fc
# 1 columns passed, passed data had 3 columns
# d8b6a56a0
# 2 columns passed, passed data had 3 columns
# d8e3b3f0c
# 7 columns passed, passed data had 8 columns
# d8e77af28
# 4 columns passed, passed data had 5 columns
# d8b804eba
# 4 columns passed, passed data had 5 columns
# d8f65ba1a
# 7 columns passed, passed data had 8 columns
# d89c92c9a
# 6 columns passed, passed data had 7 columns
# d8dc9cc0a
# 2 columns passed, passed data had 3 columns
# d8785f1f2
# 7 columns passed, passed data had 8 columns
# d8c313112
# 8 columns passed, passed data had 9 columns
# d8b2035c0
# 5 columns passed, passed data had 6 columns
# d82f20c66
# 8 columns passed, passed data had 9 columns
# d8c367424
# 4 columns passed, passed data had 5 columns
# d862b5a90
# 7 columns passed, passed data had 9 columns
# d8ea5b06c
# 4 columns passed, passed data had 5 columns
# d89a8e638
# 5 columns passed, passed data had 6 columns
# d88928d12
# 4 columns passed, passed data had 5 columns
# d888827be
# 6 columns passed, passed data had 7 columns
# d85ee07d0
# 3 columns passed, passed data had 4 columns
# d82223a9a
# 10 columns passed, passed data had 11 columns
# d8eabe0c2
# 2 columns passed, passed data had 3 columns
# d8e1c130c
# 5 columns passed, passed data had 6 columns
# d89bcbec4
# 9 columns passed, passed data had 10 columns
# d8a06de96
# 7 columns passed, passed data had 8 columns
# d8d609cc6
# 4 columns passed, passed data had 5 columns
# d8777ee18
# 8 columns passed, passed data had 9 columns
# d837becce
# 5 columns passed, passed data had 6 columns
# d8738a2bc
# 3 columns passed, passed data had 4 columns
# d82d8f082
# 1 columns passed, passed data had 2 columns
# d8e1087a8
# 5 columns passed, passed data had 6 columns
# d8ced75fc
# 2 columns passed, passed data had 3 columns
# d8e91ec12
# 5 columns passed, passed data had 9 columns
# d893095de
# 4 columns passed, passed data had 5 columns
# d831eae7e
# 4 columns passed, passed data had 5 columns
# d8f2c1940
# 8 columns passed, passed data had 9 columns
# d8872d562
# 4 columns passed, passed data had 6 columns
# d8d6e5b22
# 3 columns passed, passed data had 6 columns
# d8a3d474c
# 2 columns passed, passed data had 5 columns
# d8996d8a8
# 1 columns passed, passed data had 6 columns
# d86b3c4de
# 5 columns passed, passed data had 6 columns
# d8d0e7b30
# 1 columns passed, passed data had 2 columns
# d87c72096
# 2 columns passed, passed data had 5 columns
# d86bdf8d2
# 5 columns passed, passed data had 6 columns
# d82a10302
# 5 columns passed, passed data had 6 columns
# d8a925ad4
# 3 columns passed, passed data had 4 columns
# d8662405a
# 4 columns passed, passed data had 3 columns
# d86261ee0
# 7 columns passed, passed data had 8 columns
# d8f29f976
# 2 columns passed, passed data had 3 columns
# d8c9cf898
# 4 columns passed, passed data had 5 columns
# d883189ae
# 3 columns passed, passed data had 4 columns
# d867a36ba
# 4 columns passed, passed data had 5 columns
# d8a85436c
# 4 columns passed, passed data had 6 columns
# d8870b3cc
# 4 columns passed, passed data had 5 columns
# d8f7b6e82
# 3 columns passed, passed data had 6 columns
# d810fb4f2
# 5 columns passed, passed data had 6 columns
# d8c6f4178
# 6 columns passed, passed data had 7 columns
# d86edff8c
# 4 columns passed, passed data had 5 columns
# d8e3eb88a
# 3 columns passed, passed data had 2 columns
# d883cac4e
# 4 columns passed, passed data had 5 columns
# d8871db08
# 10 columns passed, passed data had 12 columns
# d8366a292
# 4 columns passed, passed data had 5 columns
# d8e84aa66
# 4 columns passed, passed data had 8 columns
# d8e3bfd0c
# 4 columns passed, passed data had 5 columns
# d8ec03dec
# 5 columns passed, passed data had 6 columns
# d8b4b947c
# 7 columns passed, passed data had 10 columns
# d8b024920
# 8 columns passed, passed data had 9 columns
# d81392e5e
# 5 columns passed, passed data had 6 columns
# d864b4ef4
# 5 columns passed, passed data had 6 columns
# d8c85478e
# 4 columns passed, passed data had 5 columns
# d855e74b2
# 1 columns passed, passed data had 4 columns
# d8de7eea6
# 1 columns passed, passed data had 4 columns
# d8a78939c
# 3 columns passed, passed data had 4 columns
# d8d3d3362
# 2 columns passed, passed data had 3 columns
# d8b7284e2
# 1 columns passed, passed data had 6 columns
# d87e976c8
# 6 columns passed, passed data had 7 columns
# d8df513ba
# 16 columns passed, passed data had 17 columns
# d8ad6587e
# 3 columns passed, passed data had 4 columns
# d899ac53a
# 4 columns passed, passed data had 5 columns
# d8a00cd80
# 7 columns passed, passed data had 8 columns
# d8ab7eb1e
# 2 columns passed, passed data had 3 columns
# d87e4caa6
# 1 columns passed, passed data had 2 columns
# d8994804e
# 3 columns passed, passed data had 4 columns
# d8b96327a
# 4 columns passed, passed data had 5 columns
# d8d8da31a
# 8 columns passed, passed data had 9 columns
# d8a0a31cc
# 8 columns passed, passed data had 11 columns
# d827745bc
# 4 columns passed, passed data had 5 columns
# d8792ecf4
# 5 columns passed, passed data had 6 columns
# d8c5fafd8
# 2 columns passed, passed data had 5 columns
# d8a9cb362
# 3 columns passed, passed data had 4 columns
# d8ee5452e
# 7 columns passed, passed data had 12 columns
# d873038f2
# 2 columns passed, passed data had 5 columns
# d89f8692e
# 3 columns passed, passed data had 4 columns
# d81642b9a
# 4 columns passed, passed data had 5 columns
# d8ee83f86
# 2 columns passed, passed data had 3 columns
# d86d16426
# 2 columns passed, passed data had 3 columns
# d8dc238dc
# 8 columns passed, passed data had 9 columns
# d8b642d3e
# 6 columns passed, passed data had 7 columns
# d89cd4b4a
# 4 columns passed, passed data had 5 columns
# d878b7f78
# 6 columns passed, passed data had 7 columns
# d8c3675be
# 8 columns passed, passed data had 9 columns
# d8e3a8fc6
# 1 columns passed, passed data had 3 columns
# d8bf4f26a
# 4 columns passed, passed data had 5 columns
# d867fd534
# 3 columns passed, passed data had 5 columns
# d8cf040ac
# 3 columns passed, passed data had 4 columns
# d85f4a54a
# 6 columns passed, passed data had 8 columns
# d871192b2
# 6 columns passed, passed data had 7 columns
# d88ef2680
# 4 columns passed, passed data had 5 columns
# d87f7b5e4
# 6 columns passed, passed data had 7 columns
# d831eaf0a
# 5 columns passed, passed data had 6 columns
# d8eaff5c2
# 7 columns passed, passed data had 8 columns
# d8b369f90
# 4 columns passed, passed data had 6 columns
# d8e3d6ade
# 1 columns passed, passed data had 2 columns
# d898ab2da
# 2 columns passed, passed data had 3 columns
# d867fd6b0
# 3 columns passed, passed data had 4 columns
# d8e3253ce
# 3 columns passed, passed data had 4 columns
# d8bc3a426
# 5 columns passed, passed data had 6 columns
# d8b378806
# 3 columns passed, passed data had 4 columns
# d8c52860a
# 3 columns passed, passed data had 4 columns
# d8e69fdf6
# 1 columns passed, passed data had 2 columns
# d88ac7542
# 10 columns passed, passed data had 11 columns
# d8603ffb8
# 3 columns passed, passed data had 4 columns
# d8aff5062
# 2 columns passed, passed data had 3 columns
# d8e3fa25e
# 4 columns passed, passed data had 5 columns
# d8b66184c
# 5 columns passed, passed data had 8 columns
# d8f5a2286
# 3 columns passed, passed data had 4 columns
# d8c25900a
# 7 columns passed, passed data had 8 columns
# d8e083396
# 3 columns passed, passed data had 5 columns
# d8b8ed35e
# 8 columns passed, passed data had 10 columns
# d80f19a44
# 4 columns passed, passed data had 5 columns
# d87964ef8
# 6 columns passed, passed data had 7 columns
# d84dc5e00
# 2 columns passed, passed data had 3 columns
# d8cee7b3c
# 3 columns passed, passed data had 4 columns
# d87f9935a
# 5 columns passed, passed data had 6 columns
# d885a080c
# 2 columns passed, passed data had 7 columns
# d8a75d440
# 1 columns passed, passed data had 4 columns
# d8c2591b8
# 4 columns passed, passed data had 7 columns
# d8d04d4d6
# 1 columns passed, passed data had 2 columns
# d8a919fcc
# 4 columns passed, passed data had 8 columns
# d8c997772
# 9 columns passed, passed data had 10 columns
# d868c1588
# 8 columns passed, passed data had 9 columns
# d8e6faf1c
# 3 columns passed, passed data had 4 columns
# d875a11ae
# 8 columns passed, passed data had 9 columns
# d815c50d2
# 5 columns passed, passed data had 6 columns
# d866b2238
# 1 columns passed, passed data had 4 columns
# d8e51ccfe
# 5 columns passed, passed data had 9 columns
# d8a2ea12e
# 2 columns passed, passed data had 3 columns
# d8b477a04
# 5 columns passed, passed data had 6 columns
# d8a73efea
# 3 columns passed, passed data had 5 columns
# d8ba76400
# 4 columns passed, passed data had 5 columns
# d82a3a576
# 8 columns passed, passed data had 9 columns
# d8f4a865a
# 10 columns passed, passed data had 11 columns
# d8c64e89a
# 3 columns passed, passed data had 7 columns
# d81e74174
# 5 columns passed, passed data had 6 columns
# d82a3a51c
# 2 columns passed, passed data had 3 columns
# d8bdb71f0
# 4 columns passed, passed data had 5 columns
# d8bd86b7c
# 2 columns passed, passed data had 3 columns
# d8df83bbc
# 1 columns passed, passed data had 2 columns
# d86030cd4
# 7 columns passed, passed data had 8 columns
# d89fd95fc
# 4 columns passed, passed data had 8 columns
# d8a3b47a8
# 9 columns passed, passed data had 10 columns
# d813ebc5c
# 3 columns passed, passed data had 4 columns
# d8140c1d2
# 6 columns passed, passed data had 7 columns
# d8d5fed8a
# 6 columns passed, passed data had 7 columns
# d888ccb52
# 6 columns passed, passed data had 7 columns
# d89498cec
# 6 columns passed, passed data had 7 columns
# d8b024a92
# 2 columns passed, passed data had 3 columns
# d8ba90a1c
# 5 columns passed, passed data had 9 columns
# d8e7fbab0
# 5 columns passed, passed data had 7 columns
# d878ee3a2
# 5 columns passed, passed data had 8 columns
# d8d609d48
# 4 columns passed, passed data had 6 columns
# d814d947a
# 5 columns passed, passed data had 9 columns
# d8f46fb84
# 5 columns passed, passed data had 6 columns
# d88038838
# 2 columns passed, passed data had 3 columns
# d87cadac4
# 2 columns passed, passed data had 3 columns
# d874fa034
# 5 columns passed, passed data had 6 columns
# d8e84aa20
# 6 columns passed, passed data had 7 columns
# d8a00cc04
# 4 columns passed, passed data had 1 columns
# d8d04d602
# 6 columns passed, passed data had 7 columns
# d8c7e0b40
# 5 columns passed, passed data had 9 columns
# d8eedf7d2
# 2 columns passed, passed data had 3 columns
# d8b316e3a
# 3 columns passed, passed data had 4 columns
# d88d8cc64
# 5 columns passed, passed data had 6 columns
# d8cb1d7cc
# 9 columns passed, passed data had 10 columns
# d82f20a86
# 2 columns passed, passed data had 3 columns
# d8991345c
# 3 columns passed, passed data had 4 columns
# d8f177292
# 9 columns passed, passed data had 10 columns
# d86b2258e
# 6 columns passed, passed data had 8 columns
# d87be6f78
# 7 columns passed, passed data had 11 columns
# d8954e01a
# 6 columns passed, passed data had 7 columns
# d872a642c
# 4 columns passed, passed data had 5 columns
# d884f250e
# 2 columns passed, passed data had 4 columns
# d8ac9ff5c
# 4 columns passed, passed data had 6 columns
# d8cb4817a
# 5 columns passed, passed data had 8 columns
# d8b50520a
# 6 columns passed, passed data had 7 columns
# d8ac36cfa
# 3 columns passed, passed data had 4 columns
# d8621536a
# 6 columns passed, passed data had 7 columns
# d8c327004
# 3 columns passed, passed data had 4 columns
# d8cd80a1e
# 3 columns passed, passed data had 8 columns
# d88dcb77a
# 2 columns passed, passed data had 3 columns
# d8aae8b3c
# 4 columns passed, passed data had 5 columns
# d897e43c4
# 1 columns passed, passed data had 5 columns
# d8e9bc534
# 4 columns passed, passed data had 5 columns
# d877c9c42
# 4 columns passed, passed data had 8 columns
# d8a7c235e
# 4 columns passed, passed data had 8 columns
# d813b8f64
# 2 columns passed, passed data had 3 columns
# d8aa516b0
# 3 columns passed, passed data had 5 columns
# d85d52e4a
# 2 columns passed, passed data had 3 columns
# d8637aa20
# 6 columns passed, passed data had 7 columns
# d8a635432
# 5 columns passed, passed data had 8 columns
# d8aadb5d6
# 2 columns passed, passed data had 7 columns
# d892b083a
# 5 columns passed, passed data had 6 columns
# d8edceafa
# 5 columns passed, passed data had 7 columns
# d8d172758
# 11 columns passed, passed data had 12 columns
# d8a67f5c8
# 4 columns passed, passed data had 5 columns
# d8ec82098
# 6 columns passed, passed data had 7 columns
# d82d8f140
# 10 columns passed, passed data had 11 columns
# d8f63a9dc
# 3 columns passed, passed data had 4 columns
# d86e9b738
# 2 columns passed, passed data had 3 columns
# d868e3d36
# 5 columns passed, passed data had 6 columns
# d89b9aab8
# 4 columns passed, passed data had 5 columns
# d8d41564a
# 5 columns passed, passed data had 7 columns
# d898ddafa
# 1 columns passed, passed data had 4 columns
# d8664f7dc
# 4 columns passed, passed data had 8 columns
# d8c2afb26
# 8 columns passed, passed data had 9 columns
# d8de9836a
# 6 columns passed, passed data had 7 columns
# d8ee11c56
# 3 columns passed, passed data had 4 columns
# d813170b0
# 1 columns passed, passed data had 2 columns
# d8da6685a
# list index out of range
# d8d7204f2
# 5 columns passed, passed data had 6 columns
# d8e881796
# 5 columns passed, passed data had 1 columns
# d874d77d2
# 3 columns passed, passed data had 4 columns
# d8ee34b48
# 4 columns passed, passed data had 6 columns
# d88802366
# 10 columns passed, passed data had 11 columns
# d8d684db8
# 4 columns passed, passed data had 5 columns
# d8634d156
# 2 columns passed, passed data had 3 columns
# d86a875d4
# 3 columns passed, passed data had 4 columns
# d89f07c0a
# 1 columns passed, passed data had 2 columns
# d8e6b82d4
# 6 columns passed, passed data had 7 columns
# d8d6c5e62
# 8 columns passed, passed data had 9 columns
# d8c6e9188
# 3 columns passed, passed data had 4 columns
# d8e67f9c0
# 4 columns passed, passed data had 5 columns
# d8b1d2696
# 4 columns passed, passed data had 5 columns
# d86eac6f0
# 6 columns passed, passed data had 7 columns
# d8e903bba
# 4 columns passed, passed data had 5 columns
# d862b5a18
# 5 columns passed, passed data had 6 columns
# d86c3bd80
# 5 columns passed, passed data had 9 columns
# d87b01f5e
# 2 columns passed, passed data had 3 columns
# d894e01f0
# 4 columns passed, passed data had 5 columns
# d8e50d786
# 4 columns passed, passed data had 7 columns
# d8c043a9a
# 4 columns passed, passed data had 5 columns
# d8f790c14
# 3 columns passed, passed data had 4 columns
# d8ed89a72
# 8 columns passed, passed data had 9 columns
# d8b8490b0
# 2 columns passed, passed data had 3 columns
# d81589514
# 4 columns passed, passed data had 6 columns
# d827cc6a4
# 2 columns passed, passed data had 3 columns
# d87be6d52
# 3 columns passed, passed data had 4 columns
# d864446ea
# 1 columns passed, passed data had 4 columns
# d8b5b946c
# 5 columns passed, passed data had 9 columns

# %%
len( list(document_tables.keys()))
# Out:
# 8745

# %%
documents_df.shape
# Out:
# (10475, 2)

# %%
import random

# Filter out documents that have a 'Table-1'
table_1_docs = {k: v for k, v in document_tables.items() if 'Table-1' in v}

# Select a random document with 'Table-1'
random_doc_id = random.choice(list(table_1_docs.keys()))
random_table_1 = table_1_docs[random_doc_id]['Table-1']

text = documents_df.loc[random_doc_id, 'text']
print(text)

print(random_doc_id)
random_table_1
# Out:
# The following table presents the results of operations of our Annuities segment:
# |  | Years Ended December 31, |  |  |
# |  | 2009 | 2008 | Change |
# |  | (in millions, except percentages) |
# | Revenues |  |  |  |  |
# | Management and financial advice fees | $438 | $478 | $-40 | -8% |
# | Distribution fees | 247 | 275 | -28 | -10 |
# | Net investment income | 1,323 | 652 | 671 | NM |
# | Premiums | 104 | 85 | 19 | 22 |
# | Other revenues | 153 | 128 | 25 | 20 |
# | Total revenues | 2,265 | 1,618 | 647 | 40 |
# | Banking and deposit interest expense | — | — | — | — |
# | Total net revenues | 2,265 | 1,618 | 647 | 40 |
# | Expenses |  |  |  |  |
# | Distribution expenses | 211 | 207 | 4 | 2 |
# | Interest credited to fixed accounts | 759 | 646 | 113 | 17 |
# | Benefits, claims, losses and settlement expenses | 418 | 269 | 149 | 55 |
# | Amortization of deferred acquisition costs | 37 | 576 | -539 | -94 |
# | General and administrative expense | 192 | 207 | -15 | -7 |
# | Total expenses | 1,617 | 1,905 | -288 | -15 |
# | Pretax income (loss) | $648 | $-287 | $935 | NM |
# useful life of the asset, whichever is shorter.
# Amortization and depreciation expense was $55.0 million in 2006, $52.7 million in 2005 and $53.0 million in 2004.
# The cost of repairs and maintenance is charged to operations as incurred and was $16.4 million, $17.4 million and $16.1 million in fiscal 2006, 2005 and 2004, respectively.
# The Company evaluates the recoverability of its property, equipment and intangible assets whenever indications of impairment exist in accordance with Statement of Financial Accounting Standards No.144, Accounting for the Impairment or Disposal of Long-Lived Assets (SFAS 144), and records an impairment charge against income as appropriate.
# A detail of property and equipment is as follows:
# |  | October 31, |
# |  | 2006 | 2005 |
# |  | (in thousands) |
# | Computer and other equipment | $376,999 | $351,253 |
# | Buildings | 42,695 | 21,821 |
# | Furniture and fixtures | 27,535 | 29,936 |
# | Land | 20,414 | 42,754 |
# | Leasehold improvements | 55,321 | 71,217 |
# |  | 522,964 | 516,981 |
# | Less accumulated depreciation and amortization | -382,304 | -346,786 |
# | Total property and equipment, net-1 | $140,660 | $170,195 |
# (1) During the fourth quarter of fiscal 2006, the Company entered into a sale agreement with a third party to sell a parcel of land in San Jose, California.
# The land, with a book value of $23.4 million as of October 31, 2006, has been reclassified from property, plant and equipment and reported as an asset held-for-sale within prepaid expense and other assets on the Company’s Consolidated Balance Sheet.
# Software Development Costs.
# Capitalization of software development costs begins upon the establishment of technological feasibility, which is generally the completion of a working prototype and ends upon general release of the product.
# Capitalized software development costs were approximately $3.5 million, $3.0 million and $2.7 million in fiscal 2006, 2005 and 2004, respectively.
# Amortization of software development costs is computed based on the straight-line method over the software’s estimated economic life of approximately two years.
# The Company recorded software amortization costs of $3.0 million, $2.7 million and $2.3 million in fiscal 2006, 2005 and 2004, respectively.
# Goodwill and Intangible Assets.
# Goodwill represents the excess of the aggregate purchase price over the fair value of the tangible and identifiable intangible assets acquired by the Company.
# The goodwill recorded as a result of the business combinations in the years presented is not deductible for tax purposes.
# Goodwill is not amortized, but rather is tested for impairment annually in the Company’s fiscal third quarter.
# In accordance with Statement of Financial Accounting Standards No.142, Goodwill and Other Intangible Assets (SFAS 142), the carrying amount of goodwill is tested for impairment annually, or more frequently if facts and circumstances warrant a review.
# With the adoption of SFAS 142, the Company determined that there was a single reporting unit for the purpose of goodwill impairment tests under SFAS 142.
# For purposes of assessing the impairment of goodwill, the Company estimates the value of the reporting unit using its market capitalization as the best evidence of fair value.
# This fair value is then compared to the carrying value of the reporting unit.
# In addition, the carrying value of goodwill maybe affected by the settlement of tax contingencies or the recognition of tax benefits from acquired companies in periods subsequent to the acquisition date.
# During the fiscal years ended October 31, 2006, 2005 and 2004, there were no impairments to goodwill.
# As of October 31, 2006, the carrying amount of our goodwill was $735.6 million.
# Intangible assets consist of purchased technology, contract rights intangibles, customer installed base/relationships, trademarks and tradenames, covenants not to compete, customer backlog, capitalized software and other intangibles.
# Intangible assets are amortized on a straight-line basis over their estimated
# d86dabb66
#                                          Buildings      42,695      21,821
# 0                                                         2006        2005
# 1                     Computer and other equipment    $376,999    $351,253
# 2                           Furniture and fixtures      27,535      29,936
# 3                                             Land      20,414      42,754
# 4                           Leasehold improvements      55,321      71,217
# 5                                                      522,964     516,981
# 6   Less accumulated depreciation and amortization    -382,304    -346,786
# 7              Total property and equipment, net-1    $140,660    $170,195

# %%
text = documents_df.loc[random_doc_id, 'text']
print(text)
# Out:
# The following table presents the results of operations of our Annuities segment:
# |  | Years Ended December 31, |  |  |
# |  | 2009 | 2008 | Change |
# |  | (in millions, except percentages) |
# | Revenues |  |  |  |  |
# | Management and financial advice fees | $438 | $478 | $-40 | -8% |
# | Distribution fees | 247 | 275 | -28 | -10 |
# | Net investment income | 1,323 | 652 | 671 | NM |
# | Premiums | 104 | 85 | 19 | 22 |
# | Other revenues | 153 | 128 | 25 | 20 |
# | Total revenues | 2,265 | 1,618 | 647 | 40 |
# | Banking and deposit interest expense | — | — | — | — |
# | Total net revenues | 2,265 | 1,618 | 647 | 40 |
# | Expenses |  |  |  |  |
# | Distribution expenses | 211 | 207 | 4 | 2 |
# | Interest credited to fixed accounts | 759 | 646 | 113 | 17 |
# | Benefits, claims, losses and settlement expenses | 418 | 269 | 149 | 55 |
# | Amortization of deferred acquisition costs | 37 | 576 | -539 | -94 |
# | General and administrative expense | 192 | 207 | -15 | -7 |
# | Total expenses | 1,617 | 1,905 | -288 | -15 |
# | Pretax income (loss) | $648 | $-287 | $935 | NM |
# useful life of the asset, whichever is shorter.
# Amortization and depreciation expense was $55.0 million in 2006, $52.7 million in 2005 and $53.0 million in 2004.
# The cost of repairs and maintenance is charged to operations as incurred and was $16.4 million, $17.4 million and $16.1 million in fiscal 2006, 2005 and 2004, respectively.
# The Company evaluates the recoverability of its property, equipment and intangible assets whenever indications of impairment exist in accordance with Statement of Financial Accounting Standards No.144, Accounting for the Impairment or Disposal of Long-Lived Assets (SFAS 144), and records an impairment charge against income as appropriate.
# A detail of property and equipment is as follows:
# |  | October 31, |
# |  | 2006 | 2005 |
# |  | (in thousands) |
# | Computer and other equipment | $376,999 | $351,253 |
# | Buildings | 42,695 | 21,821 |
# | Furniture and fixtures | 27,535 | 29,936 |
# | Land | 20,414 | 42,754 |
# | Leasehold improvements | 55,321 | 71,217 |
# |  | 522,964 | 516,981 |
# | Less accumulated depreciation and amortization | -382,304 | -346,786 |
# | Total property and equipment, net-1 | $140,660 | $170,195 |
# (1) During the fourth quarter of fiscal 2006, the Company entered into a sale agreement with a third party to sell a parcel of land in San Jose, California.
# The land, with a book value of $23.4 million as of October 31, 2006, has been reclassified from property, plant and equipment and reported as an asset held-for-sale within prepaid expense and other assets on the Company’s Consolidated Balance Sheet.
# Software Development Costs.
# Capitalization of software development costs begins upon the establishment of technological feasibility, which is generally the completion of a working prototype and ends upon general release of the product.
# Capitalized software development costs were approximately $3.5 million, $3.0 million and $2.7 million in fiscal 2006, 2005 and 2004, respectively.
# Amortization of software development costs is computed based on the straight-line method over the software’s estimated economic life of approximately two years.
# The Company recorded software amortization costs of $3.0 million, $2.7 million and $2.3 million in fiscal 2006, 2005 and 2004, respectively.
# Goodwill and Intangible Assets.
# Goodwill represents the excess of the aggregate purchase price over the fair value of the tangible and identifiable intangible assets acquired by the Company.
# The goodwill recorded as a result of the business combinations in the years presented is not deductible for tax purposes.
# Goodwill is not amortized, but rather is tested for impairment annually in the Company’s fiscal third quarter.
# In accordance with Statement of Financial Accounting Standards No.142, Goodwill and Other Intangible Assets (SFAS 142), the carrying amount of goodwill is tested for impairment annually, or more frequently if facts and circumstances warrant a review.
# With the adoption of SFAS 142, the Company determined that there was a single reporting unit for the purpose of goodwill impairment tests under SFAS 142.
# For purposes of assessing the impairment of goodwill, the Company estimates the value of the reporting unit using its market capitalization as the best evidence of fair value.
# This fair value is then compared to the carrying value of the reporting unit.
# In addition, the carrying value of goodwill maybe affected by the settlement of tax contingencies or the recognition of tax benefits from acquired companies in periods subsequent to the acquisition date.
# During the fiscal years ended October 31, 2006, 2005 and 2004, there were no impairments to goodwill.
# As of October 31, 2006, the carrying amount of our goodwill was $735.6 million.
# Intangible assets consist of purchased technology, contract rights intangibles, customer installed base/relationships, trademarks and tradenames, covenants not to compete, customer backlog, capitalized software and other intangibles.
# Intangible assets are amortized on a straight-line basis over their estimated

# %%
paragraphs, tables = extract(text)
for table in tables:
   table = parse_table(table.split("\n"))
   break
table
# Out:
#                 Management and financial advice fees     $438     $478   \
# 0                                                        2009     2008
# 1                                           Revenues
# 2                                  Distribution fees      247      275
# 3                              Net investment income    1,323      652
# 4                                           Premiums      104       85
# 5                                     Other revenues      153      128
# 6                                     Total revenues    2,265    1,618
# 7               Banking and deposit interest expense        —        —
# 8                                 Total net revenues    2,265    1,618
# 9                                           Expenses
# 10                             Distribution expenses      211      207
# 11               Interest credited to fixed accounts      759      646
# 12   Benefits, claims, losses and settlement expen...     418      269
# 13        Amortization of deferred acquisition costs       37      576
# 14                General and administrative expense      192      207
# 15                                    Total expenses    1,617    1,905
# 16                              Pretax income (loss)     $648    $-287
#
#        $-40    -8%
# 0    Change    None
# 1
# 2       -28    -10
# 3       671     NM
# 4        19     22
# 5        25     20
# 6       647     40
# 7         —      —
# 8       647     40
# 9
# 10        4      2
# 11      113     17
# 12      149     55
# 13     -539    -94
# 14      -15     -7
# 15     -288    -15
# 16     $935     NM
